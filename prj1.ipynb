# %% [markdown]
# ## Data collecting and organize them properly

# %%
# !git clone https://github.com/ieee8023/covid-chestxray-dataset.git
# Out:
# Cloning into 'covid-chestxray-dataset'...
# remote: Enumerating objects: 3687, done.
# remote: Total 3687 (delta 0), reused 0 (delta 0), pack-reused 3687
# Receiving objects: 100% (3687/3687), 715.78 MiB | 35.53 MiB/s, done.
# Resolving deltas: 100% (1457/1457), done.
# Checking out files: 100% (1152/1152), done.

# %%
import pandas as pd
import os
import shutil

# %%
Files_path='covid-dataset/metadata.csv'
Img_path='covid-dataset/images'

# %%
df=pd.read_csv(Files_path)
print(df.shape)
# Out:
# (930, 29)

# %%
df.head()
# Out:
#   patientid  ...  other_notes
# 0         2  ...          NaN
# 1         2  ...          NaN
# 2         2  ...          NaN
# 3         2  ...          NaN
# 4         4  ...          NaN
#
# [5 rows x 29 columns]

# %%
#now create Dataset folder in cwd 
target_dir='Dataset/Covid'
if not os.path.exists(target_dir):
  os.mkdir(target_dir)
  print("folder created of covid data")
# Out:
# folder created of covid data

# %%
cnt=0
for (i,row) in df.iterrows():
  if row['finding']=='COVID-19' and row['view']=="PA":
    cnt+=1

print(cnt)
# Out:
# 180

# %%
cnt=0

# %%
for (i,row) in df.iterrows():
  if row['finding']=='COVID-19' and row['view']=="PA":
    filename=row['filename']
    image_path=os.path.join(Img_path,filename)
    image_copy_path=os.path.join(target_dir,filename)
    shutil.copy2(image_path,image_copy_path)
    print("moving img : ",cnt)
    cnt+=1
# Out:
# moving img :  0
# moving img :  1
# moving img :  2
# moving img :  3
# moving img :  4
# moving img :  5
# moving img :  6
# moving img :  7
# moving img :  8
# moving img :  9
# moving img :  10
# moving img :  11
# moving img :  12
# moving img :  13
# moving img :  14
# moving img :  15
# moving img :  16
# moving img :  17
# moving img :  18
# moving img :  19
# moving img :  20
# moving img :  21
# moving img :  22
# moving img :  23
# moving img :  24
# moving img :  25
# moving img :  26
# moving img :  27
# moving img :  28
# moving img :  29
# moving img :  30
# moving img :  31
# moving img :  32
# moving img :  33
# moving img :  34
# moving img :  35
# moving img :  36
# moving img :  37
# moving img :  38
# moving img :  39
# moving img :  40
# moving img :  41
# moving img :  42
# moving img :  43
# moving img :  44
# moving img :  45
# moving img :  46
# moving img :  47
# moving img :  48
# moving img :  49
# moving img :  50
# moving img :  51
# moving img :  52
# ...

# %%
os.mkdir(r"Dataset/Normal")

# %% [markdown]
# ## now download for normal from kaggle

# %%
# !pip install --upgrade --force-reinstall --no-deps kaggle
# !kaggle -v
# Out:
# ...
#      |████████████████████████████████| 81kB 7.5MB/s
# ...
#   Created wheel for kaggle: filename=kaggle-1.5.7-cp36-none-any.whl size=94415 sha256=ee152f080b96a2b4f5e4279715648545b97becf0da85b4b5ad9814d50b0bebaa
#   Stored in directory: /root/.cache/pip/wheels/b3/29/26/1c933d0e10be36af91b18b82870d29004d36fbe9919ef69aa2
# Successfully built kaggle
# ...
#   Found existing installation: kaggle 1.5.6
#     Uninstalling kaggle-1.5.6:
#       Successfully uninstalled kaggle-1.5.6
# ...
# Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.
# Kaggle API 1.5.7

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-03d8f70a-3e28-43ab-b9dc-389636b368ed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-03d8f70a-3e28-43ab-b9dc-389636b368ed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"darshanmalaviya","key":"7fd1e3adf1dfbfca1962e79f8bdeb3e9"}'}

# %%
#before importing the dataset we want to use this code
# The Kaggle API client expects this file to be in ~/.kaggle,
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d pcbreviglieri/pneumonia-xray-images
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 146, in authenticate
#     self.config_file, self.config_dir))
# IOError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
# Out:
# --2020-09-01 13:58:15--  https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia/download
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /account/login?returnUrl=%2Fpaultimothymooney%2Fchest-xray-pneumonia%3Fresource%3Ddownload%26downloadHash%3D524231d90967069a0c30caec7666a304a83f41d0f0c21d0d86fd553620e64c53&message=Welcome to Kaggle! Join our community of over 5 million data scientists. Find datasets and code as well as free access to compute on our platform.&titleType=dataset-downloads&showDatasetDownloadSkip=True [following]
# ...

# %%
import shutil

# %%
shutil.make_archive('Dataset','zip','Dataset')
# Out:
# '/content/Dataset.zip'

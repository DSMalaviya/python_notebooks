# %%
#now create datasset mnually
import pandas as pd
import os
import shutil
import glob

# %%
os.mkdir('Dataset')

# %%
os.mkdir('Dataset/covid')

# %%
# !git clone https://github.com/ieee8023/covid-chestxray-dataset.git
# Out:
# Cloning into 'covid-chestxray-dataset'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 3691 (delta 0), reused 1 (delta 0), pack-reused 3687
# Receiving objects: 100% (3691/3691), 715.78 MiB | 40.77 MiB/s, done.
# Resolving deltas: 100% (1457/1457), done.
# Checking out files: 100% (1153/1153), done.

# %%
files_path='covid-chestxray-dataset/metadata.csv'
images_path='covid-chestxray-dataset/images'

# %%
df=pd.read_csv(files_path)
df.head()
# Out:
#   patientid  ...  other_notes
# 0         2  ...          NaN
# 1         2  ...          NaN
# 2         2  ...          NaN
# 3         2  ...          NaN
# 4         4  ...          NaN
#
# [5 rows x 29 columns]

# %%
Target_dir="Dataset/covid"
if not os.path.exists(Target_dir):
  os.mkdir(target_dir)
  print("folder created of covid data")

# %%
cnt=0
for (i,row) in df.iterrows():
  if row['finding']=='COVID-19' and row['view']=='PA':
    cnt+=1
print(cnt)
# Out:
# 180

# %%
cnt=0
for (i,row) in df.iterrows():
  if row['finding']=='COVID-19' and row['view']=='PA':
    filename=row['filename']
    image_path=os.path.join(images_path,filename)
    image_copy_path=os.path.join(Target_dir,filename)
    shutil.copy2(image_path,image_copy_path)
    cnt+=1
print(cnt," images are moved")
# Out:
# 180  images are moved

# %%
# !git clone https://github.com/agchung/Figure1-COVID-chestxray-dataset.git
# Out:
# Cloning into 'Figure1-COVID-chestxray-dataset'...
# remote: Enumerating objects: 112, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (97/97), done.
# remote: Total 112 (delta 28), reused 95 (delta 14), pack-reused 0
# Receiving objects: 100% (112/112), 14.13 MiB | 31.87 MiB/s, done.
# Resolving deltas: 100% (28/28), done.

# %%
Source_dir='Figure1-COVID-chestxray-dataset/images'
new_files=os.listdir(Source_dir)
old_files=os.listdir(Target_dir)
cnt=0
for f in new_files:
  image_path=os.path.join(Source_dir,f)
  image_copy_path=os.path.join(Target_dir,f)
  if(f not in old_files):
    shutil.copy2(image_path,image_copy_path)
    cnt+=1
print(cnt," images are moved")
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-21-c5137813beae> in <module>()
#       7   image_copy_path=os.path.join(Target_dir,f)
#       8   if(f not in old_files):
# ----> 9     shutil.copy2(image_path,image_copy_path)
#      10     cnt+=1
#      11 print(cnt," images are moved")
#
# /usr/lib/python3.6/shutil.py in copy2(src, dst, follow_symlinks)
#     261     if os.path.isdir(dst):
#     262         dst = os.path.join(dst, os.path.basename(src))
# --> 263     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     264     copystat(src, dst, follow_symlinks=follow_symlinks)
#     265     return dst
#
# /usr/lib/python3.6/shutil.py in copyfile(src, dst, follow_symlinks)
#     118         os.symlink(os.readlink(src), dst)
#     119     else:
# --> 120         with open(src, 'rb') as fsrc:
#     121             with open(dst, 'wb') as fdst:
#     122                 copyfileobj(fsrc, fdst)
#
# IsADirectoryError: [Errno 21] Is a directory: 'Figure1-COVID-chestxray-dataset/images/.ipynb_checkpoints'

# %%
shutil.make_archive("Figure1-COVID-chestxray-dataset/images",'zip')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-c12e25fa3de8> in <module>()
# ----> 1 shutil.make_archive("Figure1-COVID-chestxray-dataset/images",'zip')
#
# /usr/lib/python3.6/shutil.py in make_archive(base_name, format, root_dir, base_dir, verbose, dry_run, owner, group, logger)
#     804
#     805     try:
# --> 806         filename = func(base_name, base_dir, **kwargs)
#     807     finally:
#     808         if root_dir is not None:
#
# /usr/lib/python3.6/shutil.py in _make_zipfile(base_name, base_dir, verbose, dry_run, logger)
#     702                     path = os.path.normpath(os.path.join(dirpath, name))
#     703                     if os.path.isfile(path):
# --> 704                         zf.write(path, path)
#     705                         if logger is not None:
#     706                             logger.info("adding '%s'", path)
#
# /usr/lib/python3.6/zipfile.py in write(self, filename, arcname, compress_type)
#    1644         else:
#    1645             with open(filename, "rb") as src, self.open(zinfo, 'w') as dest:
# -> 1646                 shutil.copyfileobj(src, dest, 1024*8)
#    1647
#    1648     def writestr(self, zinfo_or_arcname, data, compress_type=None):
#
# /usr/lib/python3.6/shutil.py in copyfileobj(fsrc, fdst, length)
#      80         if not buf:
#      81             break
# ---> 82         fdst.write(buf)
#      83
#      84 def _samefile(src, dst):
#
# /usr/lib/python3.6/zipfile.py in write(self, data)
#    1011         self._crc = crc32(data, self._crc)
#    1012         if self._compressor:
# -> 1013             data = self._compressor.compress(data)
#    1014             self._compress_size += len(data)
#    1015         self._fileobj.write(data)
#
# KeyboardInterrupt:

# %%
shutil.copy2("Figure1-COVID-chestxray-dataset/images",'drive/My Drive/Dataset')
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-24-461be05646ec> in <module>()
# ----> 1 shutil.copy2("Figure1-COVID-chestxray-dataset/images",'drive/My Drive/Dataset')
#
# /usr/lib/python3.6/shutil.py in copy2(src, dst, follow_symlinks)
#     261     if os.path.isdir(dst):
#     262         dst = os.path.join(dst, os.path.basename(src))
# --> 263     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     264     copystat(src, dst, follow_symlinks=follow_symlinks)
#     265     return dst
#
# /usr/lib/python3.6/shutil.py in copyfile(src, dst, follow_symlinks)
#     118         os.symlink(os.readlink(src), dst)
#     119     else:
# --> 120         with open(src, 'rb') as fsrc:
#     121             with open(dst, 'wb') as fdst:
#     122                 copyfileobj(fsrc, fdst)
#
# IsADirectoryError: [Errno 21] Is a directory: 'Figure1-COVID-chestxray-dataset/images'

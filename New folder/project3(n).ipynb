# %%
import cv2
import os
import shutil

# %%
os.environ['KAGGLE_CONFIG_DIR']="/content"

# %%
# !kaggle datasets download -d amanullahasraf/covid19-pneumonia-normal-chest-xray-pa-dataset
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /content/kaggle.json'
# Downloading covid19-pneumonia-normal-chest-xray-pa-dataset.zip to /content
# 100% 1.91G/1.91G [00:19<00:00, 34.2MB/s]
# 100% 1.91G/1.91G [00:19<00:00, 105MB/s]

# %%
from zipfile import ZipFile
fname='covid19-pneumonia-normal-chest-xray-pa-dataset.zip'
with ZipFile(fname,'r') as zip:
  zip.extractall()
  print('done')
# Out:
# done

# %%
os.mkdir('covid2')
os.mkdir('normal2')
os.mkdir('pneumonia2')

# %%
# files=os.listdir('normal')
# for f in files:
#   image = cv2.imread(os.path.join('normal',f))
#   gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#   cv2.imwrite(os.path.join('normal2',f),gray)

files1=os.listdir('covid')
for f in files1:
  image = cv2.imread(os.path.join('covid',f))
  gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  cv2.imwrite(os.path.join('covid2',f'{f}.png'),gray)

# files2=os.listdir('pneumonia')
# for f in files2:
#   image = cv2.imread(os.path.join('pneumonia',f))
#   gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#   cv2.imwrite(os.path.join('pneumonia2',f),gray)

# %%
os.mkdir('Dataset')
shutil.move('covid2','Dataset')
shutil.move('normal2','Dataset')
shutil.
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-9-765b2bab43ef> in <module>()
#       2 for f in files2:
#       3   image = cv2.imread(os.path.join('normal',f))
# ----> 4   gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       5   cv2.imwrite(os.path.join('pneumonia2',f),gray)
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
from PIL import Image

im1 = Image.open(r'path where the JPG is stored\file name.jpg')
im1.save(r'path where the PNG will be stored\new file name.png')

# %%
from PIL import Image
f1=os.listdir('covid')
i=1
for j in f1:
  im=Image.open(os.path.join('covid',j))
  im.save(os.path.join('covid2',f'{i}.png'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     495     try:
# --> 496         fh = fp.fileno()
#     497         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-d1a15dc61ca0> in <module>()
#       4 for j in f1:
#       5   im=Image.open(os.path.join('covid',j))
# ----> 6   im.save(os.path.join('covid2',f'{i}.png'))
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2100
#    2101         try:
# -> 2102             save_handler(self, fp, filename)
#    2103         finally:
#    2104             # do what we can to clean up
#
# /usr/local/lib/python3.6/dist-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk)
#     898         chunk(fp, b"eXIf", exif)
#     899
# --> 900     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#     901
#     902     chunk(fp, b"IEND", b"")
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     508             else:
#     509                 while True:
# --> 510                     l, s, d = e.encode(bufsize)
#     511                     fp.write(d)
#     512                     if s:
#
# KeyboardInterrupt:

# %%
shutil.rmtree('covid2')

# %%
os.mkdir('covid2')

# %%
os.mkdir('dataset')
shutil.move('covid2','dataset')
shutil.move('normal2','dataset')
shutil.move('pneumonia2','dataset')

os.chdir('dataset')
os.rename('covid2','0')
os.rename('normal2','1')
os.rename('pneumonia2','2')

os.chdir('../')

# %%
import random
os.chdir('dataset')
if os.path.isdir('train/0/') is False:
  os.mkdir('train')
  os.mkdir('test')
  os.mkdir('valid')

  for i in range(0,3):
    shutil.move(f'{i}','train')
    os.mkdir(f'test/{i}')
    os.mkdir(f'valid/{i}')


    test_samples=random.sample(os.listdir(f'train/{i}'),100)
    for j in test_samples:
      shutil.move(f'train/{i}/{j}',f'test/{i}')

    valid_samples=random.sample(os.listdir(f'train/{i}'),200)
    for j in valid_samples:
      shutil.move(f'train/{i}/{j}',f'valid/{i}') 

os.chdir("../")

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.preprocessing import image

# %%
train_datagen=image.ImageDataGenerator(
     rescale=1./255,
    width_shift_range=.1,
    height_shift_range=.1,
    zoom_range=.1,
    shear_range=.1,
    horizontal_flip=True
                                       )

test_datagen=image.ImageDataGenerator(
    rescale=1./255
                                       )
valid_datagen=image.ImageDataGenerator(
    rescale=1./255
                                       )

# %%
train_path='dataset/train'
test_path='dataset/test'
valid_path='dataset/valid'

# %%
train_gen=train_datagen.flow_from_directory(
    train_path,
    target_size=(224,224),
    batch_size=32,
    color_mode='grayscale'
)

test_gen=test_datagen.flow_from_directory(
    test_path,
    target_size=(224,224),
    batch_size=32,
    color_mode='grayscale'
)

valid_gen=valid_datagen.flow_from_directory(
    valid_path,
    target_size=(224,224),
    batch_size=32,
    color_mode='grayscale'
)
# Out:
# Found 6042 images belonging to 3 classes.
# Found 300 images belonging to 3 classes.
# Found 600 images belonging to 3 classes.

# %%
# model = Sequential()
# model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
# model.add(BatchNormalization())
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.1))
# model.add(BatchNormalization())
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(BatchNormalization())
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.2))
# model.add(BatchNormalization())
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
# model.add(Dropout(0.2))
# model.add(BatchNormalization())
# model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# # model.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
# # model.add(Dropout(0.2))
# # model.add(BatchNormalization())
# # model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

# model.add(Flatten())
# model.add(Dense(units = 512 , activation = 'relu'))
# model.add(Dropout(0.2))
# model.add(Dense(units = 64 , activation = 'relu'))
# model.add(Dropout(0.2))
# model.add(Dense(units = 3 , activation = 'softmax'))
# model.compile(optimizer = "adam" , loss = keras.losses.categorical_crossentropy , metrics = ['accuracy'])
# model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_34 (Conv2D)           (None, 150, 150, 32)      320
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 150, 150, 32)      128
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 75, 75, 64)        18496
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 75, 75, 64)        0
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 75, 75, 64)        256
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 38, 38, 64)        0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 38, 38, 64)        36928
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 38, 38, 64)        256
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 19, 19, 64)        0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 19, 19, 128)       73856
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 19, 19, 128)       0
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 19, 19, 128)       512
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 10, 10, 256)       295168
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 10, 10, 256)       0
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 10, 10, 256)       1024
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 512)               3277312
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 3)                 195
# =================================================================
# Total params: 3,737,283
# Trainable params: 3,736,195
# Non-trainable params: 1,088
# _________________________________________________________________

# %%
model=Sequential()

model.add(Conv2D(16,padding='same',kernel_size=(3,3),activation='relu',input_shape=(224,224,1)))
model.add(Conv2D(16,padding='same',kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(32,padding='same',kernel_size=(3,3),activation='relu'))
model.add(Conv2D(32,padding='same',kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64,padding='same',kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,padding='same',kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(256,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(3,activation='softmax'))
model.compile(loss=keras.losses.binary_crossentropy,optimizer='adam',metrics=['accuracy'])

# %%
model.fit(train_gen,validation_data=valid_gen,epochs=30,batch_size=64,verbose=2,shuffle=True,steps_per_epoch=10)
# Out:
# Epoch 1/30
# 10/10 - 12s - loss: 0.6408 - accuracy: 0.3562 - val_loss: 0.6370 - val_accuracy: 0.3333
# Epoch 2/30
# 10/10 - 11s - loss: 0.6375 - accuracy: 0.3000 - val_loss: 0.6367 - val_accuracy: 0.3333
# Epoch 3/30
# 10/10 - 11s - loss: 0.6359 - accuracy: 0.3375 - val_loss: 0.6352 - val_accuracy: 0.3333
# Epoch 4/30
# 10/10 - 12s - loss: 0.6336 - accuracy: 0.3500 - val_loss: 0.6257 - val_accuracy: 0.3333
# Epoch 5/30
# 10/10 - 11s - loss: 0.6189 - accuracy: 0.3469 - val_loss: 0.6017 - val_accuracy: 0.3433
# Epoch 6/30
# 10/10 - 11s - loss: 0.6152 - accuracy: 0.4094 - val_loss: 0.6050 - val_accuracy: 0.6250
# Epoch 7/30
# 10/10 - 11s - loss: 0.5960 - accuracy: 0.4750 - val_loss: 0.5861 - val_accuracy: 0.6317
# Epoch 8/30
# 10/10 - 11s - loss: 0.5984 - accuracy: 0.5156 - val_loss: 0.6117 - val_accuracy: 0.5750
# Epoch 9/30
# 10/10 - 11s - loss: 0.6086 - accuracy: 0.5375 - val_loss: 0.5722 - val_accuracy: 0.6117
# Epoch 10/30
# 10/10 - 11s - loss: 0.5935 - accuracy: 0.5312 - val_loss: 0.5825 - val_accuracy: 0.6100
# Epoch 11/30
# 10/10 - 11s - loss: 0.6052 - accuracy: 0.5125 - val_loss: 0.5765 - val_accuracy: 0.6133
# Epoch 12/30
# 10/10 - 11s - loss: 0.5763 - accuracy: 0.5844 - val_loss: 0.5372 - val_accuracy: 0.6200
# Epoch 13/30
# 10/10 - 11s - loss: 0.5803 - accuracy: 0.5312 - val_loss: 0.5384 - val_accuracy: 0.6283
# Epoch 14/30
# 10/10 - 11s - loss: 0.5627 - accuracy: 0.5656 - val_loss: 0.5478 - val_accuracy: 0.5983
# Epoch 15/30
# 10/10 - 11s - loss: 0.5589 - accuracy: 0.5594 - val_loss: 0.5146 - val_accuracy: 0.6333
# Epoch 16/30
# 10/10 - 11s - loss: 0.5413 - accuracy: 0.5500 - val_loss: 0.5477 - val_accuracy: 0.5800
# Epoch 17/30
# 10/10 - 11s - loss: 0.5562 - accuracy: 0.5656 - val_loss: 0.5274 - val_accuracy: 0.6317
# Epoch 18/30
# 10/10 - 11s - loss: 0.5508 - accuracy: 0.5844 - val_loss: 0.5024 - val_accuracy: 0.6867
# Epoch 19/30
# 10/10 - 11s - loss: 0.5901 - accuracy: 0.5406 - val_loss: 0.5291 - val_accuracy: 0.6717
# Epoch 20/30
# 10/10 - 11s - loss: 0.5559 - accuracy: 0.5500 - val_loss: 0.5417 - val_accuracy: 0.6067
# Epoch 21/30
# 10/10 - 11s - loss: 0.5367 - accuracy: 0.5906 - val_loss: 0.4842 - val_accuracy: 0.6483
# Epoch 22/30
# 10/10 - 11s - loss: 0.5611 - accuracy: 0.5625 - val_loss: 0.5233 - val_accuracy: 0.6317
# Epoch 23/30
# 10/10 - 11s - loss: 0.5373 - accuracy: 0.5938 - val_loss: 0.4791 - val_accuracy: 0.6450
# Epoch 24/30
# 10/10 - 11s - loss: 0.5742 - accuracy: 0.5750 - val_loss: 0.5015 - val_accuracy: 0.6500
# Epoch 25/30
# 10/10 - 11s - loss: 0.5330 - accuracy: 0.6062 - val_loss: 0.4881 - val_accuracy: 0.6533
# Epoch 26/30
# 10/10 - 11s - loss: 0.5376 - accuracy: 0.5844 - val_loss: 0.4493 - val_accuracy: 0.6950
# Epoch 27/30
# 10/10 - 11s - loss: 0.5347 - accuracy: 0.5375 - val_loss: 0.4819 - val_accuracy: 0.6650
# Epoch 28/30
# 10/10 - 11s - loss: 0.5099 - accuracy: 0.6531 - val_loss: 0.4629 - val_accuracy: 0.6983
# Epoch 29/30
# 10/10 - 11s - loss: 0.4944 - accuracy: 0.6469 - val_loss: 0.4491 - val_accuracy: 0.6917
# Epoch 30/30
# 10/10 - 11s - loss: 0.5103 - accuracy: 0.6313 - val_loss: 0.4626 - val_accuracy: 0.6750

# %%
test_gen.image_shape
# Out:
# (224, 224, 1)

# %%
predictions=model.predict(test_gen)

# %%
def plot_confusion_matrix(cm,classes,normalize=False,title='Confusion Matrix',cmap=plt.cm.Blues):
  plt.imshow(cm,interpolation='nearest',cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks=np.arange(len(classes))
  plt.xticks(tick_marks,classes,rotation=45)
  plt.yticks(tick_marks,classes,rotation=0)

  if normalize:
    cm=cm.astype('float')/am.sum(axis=1)[:,np.newaxis]
    print("Normalized confusion matrix")
  else:
    print("Confusion matrix,without normalization")
  
  print(cm)

  thresh=cm.max()/2
  for i,j in itertools.product(range(cm.shape[0]),range(cm.shape[1])):
    plt.text(j,i,cm[i,j],horizontalalignment='center',color='white' if cm[i,j]>thresh else 'black')
  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
import itertools
cm=confusion_matrix(y_true=test_gen.classes,y_pred=np.argmax(predictions,axis=-1))

# %%
cm_plot_labels=['covid','normal','pneumonia']
plot_confusion_matrix(cm=cm,classes=cm_plot_labels,title='Confusion Matrix')
# Out:
# Confusion matrix,without normalization
# [[35 19 46]
#  [27 27 46]
#  [29 29 42]]

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_39 (Conv2D)           (None, 224, 224, 16)      160
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 224, 224, 16)      2320
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 112, 112, 16)      0
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 112, 112, 32)      4640
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 112, 112, 32)      9248
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 56, 56, 32)        0
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 56, 56, 64)        18496
# _________________________________________________________________
# max_pooling2d_41 (MaxPooling (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_42 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_21 (Dense)             (None, 512)               12845568
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_23 (Dense)             (None, 3)                 195
# =================================================================
# Total params: 12,987,315
# Trainable params: 12,987,315
# Non-trainable params: 0
# _________________________________________________________________

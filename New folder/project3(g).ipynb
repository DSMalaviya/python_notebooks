# %%
import pandas as pd
import os
import shutil
import glob

# %%
os.mkdir('Dataset')

# %%
os.mkdir('Dataset/covid')

# %%
# !git clone https://github.com/agchung/Actualmed-COVID-chestxray-dataset.git
# Out:
# Cloning into 'Actualmed-COVID-chestxray-dataset'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 422 (delta 1), reused 6 (delta 1), pack-reused 412
# Receiving objects: 100% (422/422), 1.56 GiB | 26.96 MiB/s, done.
# Resolving deltas: 100% (16/16), done.
# Checking out files: 100% (240/240), done.

# %%
files_path='Actualmed-COVID-chestxray-dataset/metadata.csv'
images_path='Actualmed-COVID-chestxray-dataset/images'

# %%
df=pd.read_csv(files_path)
df.head()
# Out:
#   patientid  ...                                              notes
# 0   ANON196  ...      Inconclusive, date taken (YYYYMMDD): 20200313
# 1   ANON196  ...      Inconclusive, date taken (YYYYMMDD): 20200313
# 2    ANON56  ...  Negative (covid-19 viral infection is excluded...
# 3    ANON56  ...  Negative (covid-19 viral infection is excluded...
# 4   ANON196  ...                  , date taken (YYYYMMDD): 20200318
#
# [5 rows x 13 columns]

# %%
Target_dir="Dataset/covid"
cnt=0
for (i,row) in df.iterrows():
  if row['finding']=='COVID-19' and row['view']=='PA':
    filename=row['imagename']
    image_path=os.path.join(images_path,filename)
    image_copy_path=os.path.join(Target_dir,filename)
    shutil.copy2(image_path,image_copy_path)
    cnt+=1
print(cnt," images are moved")
# Out:
# 32  images are moved

# %%
# !git clone https://github.com/ieee8023/covid-chestxray-dataset.git
# Out:
# Cloning into 'covid-chestxray-dataset'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 3691 (delta 0), reused 1 (delta 0), pack-reused 3687
# Receiving objects: 100% (3691/3691), 715.78 MiB | 29.20 MiB/s, done.
# Resolving deltas: 100% (1457/1457), done.
# Checking out files: 100% (1153/1153), done.

# %%
files_path='covid-chestxray-dataset/metadata.csv'
images_path='covid-chestxray-dataset/images'

# %%
df=pd.read_csv(files_path)

# %%
cnt=0
for (i,row) in df.iterrows():
  if row['finding']=='COVID-19' and row['view']=='PA':
    filename=row['filename']
    image_path=os.path.join(images_path,filename)
    image_copy_path=os.path.join(Target_dir,filename)
    shutil.copy2(image_path,image_copy_path)
    cnt+=1
print(cnt," images are moved")
# Out:
# 180  images are moved

# %%
shutil.copy2('drive/My Drive/Dataset/New folder.zip','.')
# Out:
# './New folder.zip'

# %%
from zipfile import ZipFile
fname='New folder.zip'
with ZipFile(fname,'r') as zip:
  zip.extractall()
  print('done')
# Out:
# done

# %%
Source_dir='New folder/Cov2'
new_files=os.listdir(Source_dir)
old_files=os.listdir(Target_dir)
cnt=0
for f in new_files:
  image_path=os.path.join(Source_dir,f)
  image_copy_path=os.path.join(Target_dir,f)
  if(f not in old_files):
    shutil.copy2(image_path,image_copy_path)
    cnt+=1
print(cnt," images are moved")
# Out:
# 186  images are moved

# %%
shutil.make_archive('Dataset','zip','Dataset')
# Out:
# '/content/Dataset.zip'

# %%
shutil.copy2('Dataset.zip','drive/My Drive/Dataset')
# Out:
# 'drive/My Drive/Dataset/Dataset.zip'

# %%
from zipfile import ZipFile
fname='data.zip'
with ZipFile(fname,'r') as zip:
  zip.extractall()
  print('done')
# Out:
# done

# %%
Source_dir='data/New folder'
new_files=os.listdir(Source_dir)
old_files=os.listdir(Target_dir)
cnt=0
for f in new_files:
  image_path=os.path.join(Source_dir,f)
  image_copy_path=os.path.join(Target_dir,f)
  if(f not in old_files):
    shutil.copy2(image_path,image_copy_path)
    cnt+=1
print(cnt," images are moved")
# Out:
# 29  images are moved

# %%
shutil.make_archive('Dataset','zip','Dataset')
# Out:
# '/content/Dataset.zip'

# %%
shutil.copy2('Dataset1.zip','drive/My Drive/Dataset')
# Out:
# 'drive/My Drive/Dataset/Dataset1.zip'

# %%
files=os.listdir('Dataset/covid')
count=1
for f in files:
  count+=1
print(count)
# Out:
# 428

# %%
##now make normal folder and pneumonia folder and add normal and pnumonia images into it

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content"
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia
# Out:
# ...
#  99% 2.27G/2.29G [00:39<00:00, 57.3MB/s]
# 100% 2.29G/2.29G [00:39<00:00, 62.4MB/s]

# %%
from zipfile import ZipFile
fname='chest-xray-pneumonia.zip'
with ZipFile(fname,'r') as zip:
  zip.extractall()
  print('done')
# Out:
# done

# %%
os.mkdir('Dataset/normal')

# %%
Kaggle_file_path='chest_xray/train/NORMAL'
Target_path='Dataset/normal'

# %%
image_names=os.listdir(Kaggle_file_path)

# %%
import random
random.shuffle(image_names)

# %%
cnt=1
for i in range(1000):
  image_name=image_names[i]
  image_path=os.path.join(Kaggle_file_path,image_name)
  target_path=os.path.join(Target_path,image_name)
  shutil.copy2(image_path,target_path)
  cnt+=1
  print("coping img:",cnt)
# Out:
# coping img: 2
# coping img: 3
# coping img: 4
# coping img: 5
# coping img: 6
# coping img: 7
# coping img: 8
# coping img: 9
# coping img: 10
# coping img: 11
# coping img: 12
# coping img: 13
# coping img: 14
# coping img: 15
# coping img: 16
# coping img: 17
# coping img: 18
# coping img: 19
# coping img: 20
# coping img: 21
# coping img: 22
# coping img: 23
# coping img: 24
# coping img: 25
# coping img: 26
# coping img: 27
# coping img: 28
# coping img: 29
# coping img: 30
# coping img: 31
# coping img: 32
# coping img: 33
# coping img: 34
# coping img: 35
# coping img: 36
# coping img: 37
# coping img: 38
# coping img: 39
# coping img: 40
# coping img: 41
# coping img: 42
# coping img: 43
# coping img: 44
# coping img: 45
# coping img: 46
# coping img: 47
# coping img: 48
# coping img: 49
# coping img: 50
# coping img: 51
# coping img: 52
# coping img: 53
# coping img: 54
# coping img: 55
# coping img: 56
# coping img: 57
# coping img: 58
# coping img: 59
# coping img: 60
# ...

# %%
os.mkdir('Dataset/pneumonia')

# %%
Kaggle_file_path='chest_xray/train/PNEUMONIA'
Target_path='Dataset/pneumonia'

# %%
image_names=os.listdir(Kaggle_file_path)

# %%
import random
random.shuffle(image_names)

# %%
cnt=1
for i in range(1000):
  image_name=image_names[i]
  image_path=os.path.join(Kaggle_file_path,image_name)
  target_path=os.path.join(Target_path,image_name)
  shutil.copy2(image_path,target_path)
  cnt+=1
  print("coping img:",cnt)
# Out:
# coping img: 2
# coping img: 3
# coping img: 4
# coping img: 5
# coping img: 6
# coping img: 7
# coping img: 8
# coping img: 9
# coping img: 10
# coping img: 11
# coping img: 12
# coping img: 13
# coping img: 14
# coping img: 15
# coping img: 16
# coping img: 17
# coping img: 18
# coping img: 19
# coping img: 20
# coping img: 21
# coping img: 22
# coping img: 23
# coping img: 24
# coping img: 25
# coping img: 26
# coping img: 27
# coping img: 28
# coping img: 29
# coping img: 30
# coping img: 31
# coping img: 32
# coping img: 33
# coping img: 34
# coping img: 35
# coping img: 36
# coping img: 37
# coping img: 38
# coping img: 39
# coping img: 40
# coping img: 41
# coping img: 42
# coping img: 43
# coping img: 44
# coping img: 45
# coping img: 46
# coping img: 47
# coping img: 48
# coping img: 49
# coping img: 50
# coping img: 51
# coping img: 52
# coping img: 53
# coping img: 54
# coping img: 55
# coping img: 56
# coping img: 57
# coping img: 58
# coping img: 59
# coping img: 60
# ...

# %%
shutil.make_archive('Dataset','zip','Dataset')
# Out:
# '/content/Dataset.zip'

# %%
shutil.copy2('Dataset.zip','drive/My Drive/Dataset')
# Out:
# 'drive/My Drive/Dataset/Dataset.zip'
